# %%
import pandas as pd
import numpy as np
import random

np.random.seed(42)

regions = ['North', 'South', 'East', 'West']
types = ['Residential', 'Commercial']
statuses = ['Paid', 'Unpaid', '', np.nan]
tariffs = ['T1', 'T2', 'T3']
remarks = ['OK', 'Check meter', 'Replaced', '', np.nan, 'Duplicate']

data = []
for i in range(200):
    date_format = random.choice(['%Y-%m-%d', '%d/%m/%Y', '%m-%d-%Y'])
    date = pd.Timestamp('2023-01-01') + pd.to_timedelta(random.randint(0, 180), unit='D')
    formatted_date = date.strftime(date_format) if random.random() > 0.05 else ''

    row = {
        'CustomerID': f"C{str(i+1).zfill(4)}",
        'MeterID': f"M{str(random.randint(1000, 9999))}",
        'Region': random.choice(regions),
        'ConnectionType': random.choice(types),
        'ReadingDate': formatted_date,
        'Energy_kWh': random.choice([round(random.uniform(100, 1200), 2), '', np.nan, 99999]),
        'BillingAmount': random.choice([round(random.uniform(500, 5000), 2), 'NA', '', np.nan]),
        'PaymentStatus': random.choice(statuses),
        'TariffCode': random.choice(tariffs),
        'Remarks': random.choice(remarks)
    }
    data.append(row)

df = pd.DataFrame(data)
df.to_csv('utility_meter_readings.csv', index=False)
print("✅ Dataset saved as 'utility_meter_readings.csv'")
# Out:
# ✅ Dataset saved as 'utility_meter_readings.csv'

# %%
df = pd.read_csv('utility_meter_readings.csv')
df1 = df

# %%
df1
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 0        C0001   M6587   East     Commercial  01/02/2023      753.59
# 1        C0002   M9122   East    Residential  2023-03-13    99999.00
# 2        C0003   M1018  North     Commercial  03/03/2023    99999.00
# 3        C0004   M1615   West     Commercial  2023-01-23         NaN
# 4        C0005   M7523  North    Residential  09/02/2023         NaN
# ..         ...     ...    ...            ...         ...         ...
# 195      C0196   M7600  North     Commercial  2023-03-25    99999.00
# 196      C0197   M2103   East    Residential  22/05/2023    99999.00
# 197      C0198   M8002  South     Commercial  06-25-2023      581.91
# 198      C0199   M8029   West    Residential  2023-06-12         NaN
# 199      C0200   M6029  South     Commercial  24/04/2023         NaN
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 0              NaN          Paid         T3  Check meter
# 1              NaN          Paid         T3          NaN
# 2              NaN          Paid         T2     Replaced
# 3              NaN           NaN         T2  Check meter
# 4              NaN           NaN         T2           OK
# ..             ...           ...        ...          ...
# 195        2032.17          Paid         T3           OK
# 196            NaN          Paid         T3  Check meter
# 197            NaN           NaN         T2          NaN
# 198        1869.82        Unpaid         T1  Check meter
# 199            NaN           NaN         T1     Replaced
#
# [200 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      200 non-null    object
#  1   MeterID         200 non-null    object
#  2   Region          200 non-null    object
#  3   ConnectionType  200 non-null    object
#  4   ReadingDate     191 non-null    object
#  5   Energy_kWh      110 non-null    float64
#  6   BillingAmount   51 non-null     float64
#  7   PaymentStatus   99 non-null     object
#  8   TariffCode      200 non-null    object
#  9   Remarks         140 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 15.8+ KB

# %%
df1.isna().sum()
# Out:
# CustomerID          0
# MeterID             0
# Region              0
# ConnectionType      0
# ReadingDate         9
# Energy_kWh         90
# BillingAmount     149
# PaymentStatus     101
# TariffCode          0
# Remarks            60
# dtype: int64

# %% [markdown]
# # Category: Missing & Format Fixes

# %% [markdown]
# ## 1.	Replace all '', 'NA', and ' ' with np.nan

# %%
for col in df1.columns:
  df1[col] = df1[col].astype(str).replace(to_replace=r'^\s*$|^NA$', value=np.nan, regex=True)

# %%
df1.isna().sum()
# Out:
# CustomerID        0
# MeterID           0
# Region            0
# ConnectionType    0
# ReadingDate       0
# Energy_kWh        0
# BillingAmount     0
# PaymentStatus     0
# TariffCode        0
# Remarks           0
# dtype: int64

# %% [markdown]
# ## 2.	Convert ReadingDate to datetime (handle mixed formats)

# %%
df1['ReadingDate'] = pd.to_datetime(df1['ReadingDate'], errors='coerce', format='mixed')
df1['ReadingDate'].fillna(method='ffill', inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      200 non-null    object
#  1   MeterID         200 non-null    object
#  2   Region          200 non-null    object
#  3   ConnectionType  200 non-null    object
#  4   ReadingDate     200 non-null    datetime64[ns]
#  5   Energy_kWh      200 non-null    object
#  6   BillingAmount   200 non-null    object
#  7   PaymentStatus   200 non-null    object
#  8   TariffCode      200 non-null    object
#  9   Remarks         200 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 15.8+ KB
# C:\Users\AjayGangwani\AppData\Local\Temp\ipykernel_3772\3883244061.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['ReadingDate'].fillna(method='ffill', inplace=True)
# C:\Users\AjayGangwani\AppData\Local\Temp\ipykernel_3772\3883244061.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1['ReadingDate'].fillna(method='ffill', inplace=True)

# %% [markdown]
# ## 3.	Fill missing Energy_kWh with median per Region

# %%
df1['Energy_kWh'] = pd.to_numeric(df1['Energy_kWh'], errors='coerce')
median_by_region = df1.groupby('Region')['Energy_kWh'].median()
for region in df1['Region'].unique():
    df1.loc[(df1['Region'] == region) & (df1['Energy_kWh'].isna()), 'Energy_kWh'] = median_by_region[region]

df1['Energy_kWh']
# Out:
# 0        753.59
# 1      99999.00
# 2      99999.00
# 3      99999.00
# 4       1075.76
#          ...
# 195    99999.00
# 196    99999.00
# 197      581.91
# 198    99999.00
# 199     1038.35
# Name: Energy_kWh, Length: 200, dtype: float64

# %% [markdown]
# ## 4.	Fill missing BillingAmount with 0 and convert to float

# %%
df1['BillingAmount'] = pd.to_numeric(df1['BillingAmount'], errors='coerce')
df1['BillingAmount'] = df1['BillingAmount'].fillna(0)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      200 non-null    object
#  1   MeterID         200 non-null    object
#  2   Region          200 non-null    object
#  3   ConnectionType  200 non-null    object
#  4   ReadingDate     200 non-null    datetime64[ns]
#  5   Energy_kWh      200 non-null    float64
#  6   BillingAmount   200 non-null    float64
#  7   PaymentStatus   200 non-null    object
#  8   TariffCode      200 non-null    object
#  9   Remarks         200 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 15.8+ KB

# %% [markdown]
# ## 5. Drop rows where CustomerID or MeterID is missing

# %%
df1 = df1.dropna(subset=['CustomerID', 'MeterID'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      200 non-null    object
#  1   MeterID         200 non-null    object
#  2   Region          200 non-null    object
#  3   ConnectionType  200 non-null    object
#  4   ReadingDate     200 non-null    datetime64[ns]
#  5   Energy_kWh      200 non-null    float64
#  6   BillingAmount   200 non-null    float64
#  7   PaymentStatus   200 non-null    object
#  8   TariffCode      200 non-null    object
#  9   Remarks         200 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 15.8+ KB

# %% [markdown]
# # Category: String & Categorical Cleanup

# %% [markdown]
# ## 6. Strip whitespace and standardize PaymentStatus to title case

# %%
df1['PaymentStatus'] = df1['PaymentStatus'].astype('string')
df1['PaymentStatus'] = df1['PaymentStatus'].str.strip().str.title()
df1
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 0        C0001   M6587   East     Commercial  2023-01-02      753.59
# 1        C0002   M9122   East    Residential  2023-03-13    99999.00
# 2        C0003   M1018  North     Commercial  2023-03-03    99999.00
# 3        C0004   M1615   West     Commercial  2023-01-23    99999.00
# 4        C0005   M7523  North    Residential  2023-09-02     1075.76
# ..         ...     ...    ...            ...         ...         ...
# 195      C0196   M7600  North     Commercial  2023-03-25    99999.00
# 196      C0197   M2103   East    Residential  2023-05-22    99999.00
# 197      C0198   M8002  South     Commercial  2023-06-25      581.91
# 198      C0199   M8029   West    Residential  2023-06-12    99999.00
# 199      C0200   M6029  South     Commercial  2023-04-24     1038.35
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 0             0.00          Paid         T3  Check meter
# 1             0.00          Paid         T3          nan
# 2             0.00          Paid         T2     Replaced
# 3             0.00           Nan         T2  Check meter
# 4             0.00           Nan         T2           OK
# ..             ...           ...        ...          ...
# 195        2032.17          Paid         T3           OK
# 196           0.00          Paid         T3  Check meter
# 197           0.00           Nan         T2          nan
# 198        1869.82        Unpaid         T1  Check meter
# 199           0.00           Nan         T1     Replaced
#
# [200 rows x 10 columns]

# %% [markdown]
# ## 7. Replace missing PaymentStatus with 'Unknown'

# %%
df1['PaymentStatus'] = df1['PaymentStatus'].replace('Nan', 'Unknown')
df1
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 0        C0001   M6587   East     Commercial  2023-01-02      753.59
# 1        C0002   M9122   East    Residential  2023-03-13    99999.00
# 2        C0003   M1018  North     Commercial  2023-03-03    99999.00
# 3        C0004   M1615   West     Commercial  2023-01-23    99999.00
# 4        C0005   M7523  North    Residential  2023-09-02     1075.76
# ..         ...     ...    ...            ...         ...         ...
# 195      C0196   M7600  North     Commercial  2023-03-25    99999.00
# 196      C0197   M2103   East    Residential  2023-05-22    99999.00
# 197      C0198   M8002  South     Commercial  2023-06-25      581.91
# 198      C0199   M8029   West    Residential  2023-06-12    99999.00
# 199      C0200   M6029  South     Commercial  2023-04-24     1038.35
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 0             0.00          Paid         T3  Check meter
# 1             0.00          Paid         T3          nan
# 2             0.00          Paid         T2     Replaced
# 3             0.00       Unknown         T2  Check meter
# 4             0.00       Unknown         T2           OK
# ..             ...           ...        ...          ...
# 195        2032.17          Paid         T3           OK
# 196           0.00          Paid         T3  Check meter
# 197           0.00       Unknown         T2          nan
# 198        1869.82        Unpaid         T1  Check meter
# 199           0.00       Unknown         T1     Replaced
#
# [200 rows x 10 columns]

# %% [markdown]
# ## 8. Normalize TariffCode to uppercase and validate against known codes

# %%
df1['TariffCode'] = df1['TariffCode'].str.upper()
df1['TariffCode'].isin(['T1', 'T2', 'T3'])
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 195    True
# 196    True
# 197    True
# 198    True
# 199    True
# Name: TariffCode, Length: 200, dtype: bool

# %% [markdown]
# ## 9. Remove rows where Remarks contains 'Duplicate'

# %%
masked_data = df1[df1['Remarks'] == 'Duplicate'].index
df1.drop(masked_data, inplace=True)
df1
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 0        C0001   M6587   East     Commercial  2023-01-02      753.59
# 1        C0002   M9122   East    Residential  2023-03-13    99999.00
# 2        C0003   M1018  North     Commercial  2023-03-03    99999.00
# 3        C0004   M1615   West     Commercial  2023-01-23    99999.00
# 4        C0005   M7523  North    Residential  2023-09-02     1075.76
# ..         ...     ...    ...            ...         ...         ...
# 195      C0196   M7600  North     Commercial  2023-03-25    99999.00
# 196      C0197   M2103   East    Residential  2023-05-22    99999.00
# 197      C0198   M8002  South     Commercial  2023-06-25      581.91
# 198      C0199   M8029   West    Residential  2023-06-12    99999.00
# 199      C0200   M6029  South     Commercial  2023-04-24     1038.35
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 0             0.00          Paid         T3  Check meter
# 1             0.00          Paid         T3          nan
# 2             0.00          Paid         T2     Replaced
# 3             0.00       Unknown         T2  Check meter
# 4             0.00       Unknown         T2           OK
# ..             ...           ...        ...          ...
# 195        2032.17          Paid         T3           OK
# 196           0.00          Paid         T3  Check meter
# 197           0.00       Unknown         T2          nan
# 198        1869.82        Unpaid         T1  Check meter
# 199           0.00       Unknown         T1     Replaced
#
# [173 rows x 10 columns]

# %% [markdown]
# ## 10 .Standardize ConnectionType to 'Residential' or 'Commercial' only

# %%
df1['ConnectionType'].str.strip().str.title()
df1['ConnectionType'].where(df1['ConnectionType'].isin(['Residential','Commercial']), np.nan)
# Out:
# 0       Commercial
# 1      Residential
# 2       Commercial
# 3       Commercial
# 4      Residential
#           ...
# 195     Commercial
# 196    Residential
# 197     Commercial
# 198    Residential
# 199     Commercial
# Name: ConnectionType, Length: 173, dtype: object

# %% [markdown]
# # Category: Filtering & Searching

# %% [markdown]
# ## 11. Filter all Unpaid customers with usage > 1000 kWh

# %%
df1.query("PaymentStatus == 'Unpaid' & Energy_kWh > 1000")
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 11       C0012   M4035  South     Commercial  2023-09-05    1038.350
# 14       C0015   M3145   West    Residential  2023-01-28   99999.000
# 15       C0016   M7787   East    Residential  2023-01-06   50497.985
# 20       C0021   M5820   West    Residential  2023-05-06   99999.000
# 46       C0047   M1619  South     Commercial  2023-05-02   99999.000
# 57       C0058   M3670   West     Commercial  2023-05-05   99999.000
# 61       C0062   M6072  North     Commercial  2023-03-10    1075.760
# 62       C0063   M1974   West     Commercial  2023-04-18   99999.000
# 68       C0069   M8354   East    Residential  2023-03-14   50497.985
# 72       C0073   M5046  South    Residential  2023-03-14    1128.240
# 75       C0076   M4636  North    Residential  2023-01-21    1075.760
# 76       C0077   M4528   East    Residential  2023-03-16   50497.985
# 77       C0078   M4610  North     Commercial  2023-04-17    1075.760
# 81       C0082   M7924  North    Residential  2023-04-06    1075.760
# 86       C0087   M9399   East    Residential  2023-01-12   50497.985
# 89       C0090   M9594  South     Commercial  2023-01-27    1038.350
# 92       C0093   M4630   East    Residential  2023-02-01   50497.985
# 107      C0108   M8272   East    Residential  2023-02-02   50497.985
# 110      C0111   M7787   East     Commercial  2023-10-03   50497.985
# 113      C0114   M1730  South    Residential  2023-04-21    1182.880
# 114      C0115   M9796  North    Residential  2023-04-24    1075.760
# 128      C0129   M4457   East    Residential  2023-09-05   99999.000
# 129      C0130   M6062   West     Commercial  2023-10-03   99999.000
# 130      C0131   M2477   West    Residential  2023-02-06   99999.000
# 131      C0132   M9703   West     Commercial  2023-02-06   99999.000
# 135      C0136   M9181   East    Residential  2023-02-02   50497.985
# 140      C0141   M5061  South    Residential  2023-01-09   99999.000
# 154      C0155   M3116   East    Residential  2023-08-05   50497.985
# 169      C0170   M7866   West    Residential  2023-02-04    1111.870
# 173      C0174   M1877  South     Commercial  2023-03-09    1038.350
# 183      C0184   M6778   West     Commercial  2023-06-18   99999.000
# 185      C0186   M9811   West    Residential  2023-04-13   99999.000
# 191      C0192   M2224  North    Residential  2023-06-07    1075.760
# 192      C0193   M3248   West    Residential  2023-06-30    1155.240
# 198      C0199   M8029   West    Residential  2023-06-12   99999.000
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 11            0.00        Unpaid         T3           OK
# 14         1397.04        Unpaid         T1     Replaced
# 15            0.00        Unpaid         T3           OK
# 20            0.00        Unpaid         T2           OK
# 46          721.36        Unpaid         T2          nan
# 57            0.00        Unpaid         T2          nan
# 61            0.00        Unpaid         T3  Check meter
# 62         1570.33        Unpaid         T3  Check meter
# 68         4232.83        Unpaid         T1           OK
# 72            0.00        Unpaid         T1           OK
# 75         1748.59        Unpaid         T3  Check meter
# 76            0.00        Unpaid         T3          nan
# 77            0.00        Unpaid         T2           OK
# 81            0.00        Unpaid         T3          nan
# 86            0.00        Unpaid         T3          nan
# 89         2142.55        Unpaid         T3          nan
# 92            0.00        Unpaid         T2           OK
# 107           0.00        Unpaid         T1          nan
# 110        3700.77        Unpaid         T2           OK
# 113        4890.05        Unpaid         T2  Check meter
# 114           0.00        Unpaid         T3          nan
# 128         593.99        Unpaid         T3          nan
# 129           0.00        Unpaid         T1           OK
# 130         795.36        Unpaid         T2          nan
# 131        1412.64        Unpaid         T2     Replaced
# 135           0.00        Unpaid         T2          nan
# 140           0.00        Unpaid         T3  Check meter
# 154           0.00        Unpaid         T3          nan
# 169           0.00        Unpaid         T1           OK
# 173           0.00        Unpaid         T2          nan
# 183        3291.81        Unpaid         T3           OK
# 185           0.00        Unpaid         T3          nan
# 191           0.00        Unpaid         T3     Replaced
# 192           0.00        Unpaid         T1     Replaced
# 198        1869.82        Unpaid         T1  Check meter

# %% [markdown]
# ## 12. Select customers from South region with TariffCode == 'T2'

# %%
df1.query("Region == 'South' & TariffCode == 'T2'")
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 46       C0047   M1619  South     Commercial  2023-05-02    99999.00
# 47       C0048   M8316  South    Residential  2023-01-05      620.25
# 56       C0057   M6383  South     Commercial  2023-01-08     1038.35
# 90       C0091   M4458  South     Commercial  2023-01-14    99999.00
# 103      C0104   M1086  South     Commercial  2023-06-15    99999.00
# 111      C0112   M3054  South    Residential  2023-04-04      157.33
# 113      C0114   M1730  South    Residential  2023-04-21     1182.88
# 124      C0125   M1032  South     Commercial  2023-05-29     1010.47
# 126      C0127   M8222  South     Commercial  2023-06-21     1038.35
# 127      C0128   M1414  South     Commercial  2023-03-28     1038.35
# 149      C0150   M4979  South    Residential  2023-06-19    99999.00
# 150      C0151   M2028  South    Residential  2023-06-27     1038.35
# 156      C0157   M2830  South     Commercial  2023-05-11     1038.35
# 168      C0169   M6760  South     Commercial  2023-02-04    99999.00
# 173      C0174   M1877  South     Commercial  2023-03-09     1038.35
# 197      C0198   M8002  South     Commercial  2023-06-25      581.91
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 46          721.36        Unpaid         T2          nan
# 47            0.00       Unknown         T2          nan
# 56            0.00          Paid         T2          nan
# 90            0.00       Unknown         T2     Replaced
# 103        4808.33          Paid         T2          nan
# 111        1121.93       Unknown         T2     Replaced
# 113        4890.05        Unpaid         T2  Check meter
# 124           0.00          Paid         T2           OK
# 126           0.00       Unknown         T2          nan
# 127           0.00       Unknown         T2           OK
# 149           0.00          Paid         T2           OK
# 150           0.00       Unknown         T2           OK
# 156           0.00       Unknown         T2          nan
# 168         868.85       Unknown         T2     Replaced
# 173           0.00        Unpaid         T2          nan
# 197           0.00       Unknown         T2          nan

# %% [markdown]
# ## 13. Filter readings between March and May 2023

# %%
df1[df1['ReadingDate'].between('2023-03-01', '2023-05-31')]
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 1        C0002   M9122   East    Residential  2023-03-13    99999.00
# 2        C0003   M1018  North     Commercial  2023-03-03    99999.00
# 9        C0010   M3965   West     Commercial  2023-03-31    99999.00
# 12       C0013   M6083  South    Residential  2023-04-12      235.56
# 16       C0017   M8123  North    Residential  2023-05-01     1075.76
# ..         ...     ...    ...            ...         ...         ...
# 187      C0188   M6786  South    Residential  2023-04-29      496.53
# 193      C0194   M2387  North     Commercial  2023-05-04      409.59
# 195      C0196   M7600  North     Commercial  2023-03-25    99999.00
# 196      C0197   M2103   East    Residential  2023-05-22    99999.00
# 199      C0200   M6029  South     Commercial  2023-04-24     1038.35
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 1             0.00          Paid         T3          nan
# 2             0.00          Paid         T2     Replaced
# 9          1478.62          Paid         T3          nan
# 12         1798.40       Unknown         T3  Check meter
# 16            0.00          Paid         T1     Replaced
# ..             ...           ...        ...          ...
# 187           0.00        Unpaid         T1           OK
# 193           0.00       Unknown         T2           OK
# 195        2032.17          Paid         T3           OK
# 196           0.00          Paid         T3  Check meter
# 199           0.00       Unknown         T1     Replaced
#
# [76 rows x 10 columns]

# %% [markdown]
# ## 14. Find customers with BillingAmount > 4000 and Energy_kWh < 500

# %%
df1.query("BillingAmount > 4000 & Energy_kWh < 500")
# Out:
# Empty DataFrame
# Columns: [CustomerID, MeterID, Region, ConnectionType, ReadingDate, Energy_kWh, BillingAmount, PaymentStatus, TariffCode, Remarks]
# Index: []

# %% [markdown]
# ## 15. Use .query() to extract all Commercial connections with missing remarks

# %%
df1.query("Remarks == 'nan' & ConnectionType == 'Commercial'")
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 9        C0010   M3965   West     Commercial  2023-03-31    99999.00
# 28       C0029   M2751  South     Commercial  2023-02-07    99999.00
# 44       C0045   M9466  North     Commercial  2023-03-09     1142.50
# 46       C0047   M1619  South     Commercial  2023-05-02    99999.00
# 56       C0057   M6383  South     Commercial  2023-01-08     1038.35
# 57       C0058   M3670   West     Commercial  2023-05-05    99999.00
# 64       C0065   M6074  North     Commercial  2023-06-30     1075.76
# 65       C0066   M3386  South     Commercial  2023-04-22     1038.35
# 78       C0079   M9724   West     Commercial  2023-02-08    99999.00
# 84       C0085   M9449   West     Commercial  2023-06-15    99999.00
# 89       C0090   M9594  South     Commercial  2023-01-27     1038.35
# 102      C0103   M9004   East     Commercial  2023-01-25    99999.00
# 103      C0104   M1086  South     Commercial  2023-06-15    99999.00
# 109      C0110   M9456   West     Commercial  2023-04-13      495.54
# 112      C0113   M7657   West     Commercial  2023-05-19    99999.00
# 121      C0122   M3948   West     Commercial  2023-10-06    99999.00
# 126      C0127   M8222  South     Commercial  2023-06-21     1038.35
# 147      C0148   M9258  North     Commercial  2023-05-09     1075.76
# 151      C0152   M4884  North     Commercial  2023-03-02      122.99
# 156      C0157   M2830  South     Commercial  2023-05-11     1038.35
# 160      C0161   M7550   West     Commercial  2023-01-07    99999.00
# 166      C0167   M6543   East     Commercial  2023-03-04      166.10
# 173      C0174   M1877  South     Commercial  2023-03-09     1038.35
# 180      C0181   M5590  South     Commercial  2023-03-04    99999.00
# 197      C0198   M8002  South     Commercial  2023-06-25      581.91
#
#      BillingAmount PaymentStatus TariffCode Remarks
# 9          1478.62          Paid         T3     nan
# 28            0.00       Unknown         T3     nan
# 44         3390.49       Unknown         T2     nan
# 46          721.36        Unpaid         T2     nan
# 56            0.00          Paid         T2     nan
# 57            0.00        Unpaid         T2     nan
# 64          878.06       Unknown         T3     nan
# 65         3960.23       Unknown         T3     nan
# 78            0.00          Paid         T3     nan
# 84            0.00          Paid         T2     nan
# 89         2142.55        Unpaid         T3     nan
# 102        4783.11          Paid         T3     nan
# 103        4808.33          Paid         T2     nan
# 109           0.00          Paid         T3     nan
# 112        3155.87       Unknown         T1     nan
# 121        4795.69       Unknown         T1     nan
# 126           0.00       Unknown         T2     nan
# 147           0.00       Unknown         T3     nan
# 151           0.00        Unpaid         T3     nan
# 156           0.00       Unknown         T2     nan
# 160           0.00          Paid         T2     nan
# 166           0.00       Unknown         T2     nan
# 173           0.00        Unpaid         T2     nan
# 180        4185.63       Unknown         T3     nan
# 197           0.00       Unknown         T2     nan

# %% [markdown]
# ## 16. Sort by ReadingDate descending and extract top 10 recent readings

# %%
df1.sort_values(by=['ReadingDate'], ascending=False)
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 121      C0122   M3948   West     Commercial  2023-10-06   99999.000
# 175      C0176   M7456  North     Commercial  2023-10-05   99999.000
# 110      C0111   M7787   East     Commercial  2023-10-03   50497.985
# 59       C0060   M9780   East     Commercial  2023-10-03   50497.985
# 129      C0130   M6062   West     Commercial  2023-10-03   99999.000
# ..         ...     ...    ...            ...         ...         ...
# 47       C0048   M8316  South    Residential  2023-01-05     620.250
# 144      C0145   M5546   East    Residential  2023-01-04   50497.985
# 0        C0001   M6587   East     Commercial  2023-01-02     753.590
# 7        C0008   M8168   West     Commercial  2023-01-02   99999.000
# 49       C0050   M3697   West    Residential  2023-01-01     113.830
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 121        4795.69       Unknown         T1          nan
# 175           0.00       Unknown         T3     Replaced
# 110        3700.77        Unpaid         T2           OK
# 59            0.00       Unknown         T3  Check meter
# 129           0.00        Unpaid         T1           OK
# ..             ...           ...        ...          ...
# 47            0.00       Unknown         T2          nan
# 144           0.00       Unknown         T2          nan
# 0             0.00          Paid         T3  Check meter
# 7             0.00       Unknown         T1     Replaced
# 49            0.00       Unknown         T2          nan
#
# [173 rows x 10 columns]

# %% [markdown]
# ## 17. Sort by Region and then by Energy_kWh ascending

# %%
df1.sort_values(by=['Region','Energy_kWh'], ascending=[True, False])
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 1        C0002   M9122   East    Residential  2023-03-13    99999.00
# 29       C0030   M3272   East     Commercial  2023-02-18    99999.00
# 30       C0031   M8481   East     Commercial  2023-01-18    99999.00
# 66       C0067   M8110   East     Commercial  2023-01-23    99999.00
# 99       C0100   M7124   East     Commercial  2023-06-12    99999.00
# ..         ...     ...    ...            ...         ...         ...
# 70       C0071   M6925   West    Residential  2023-04-23      776.28
# 19       C0020   M4721   West     Commercial  2023-05-29      683.00
# 176      C0177   M4212   West    Residential  2023-05-26      639.25
# 109      C0110   M9456   West     Commercial  2023-04-13      495.54
# 49       C0050   M3697   West    Residential  2023-01-01      113.83
#
#      BillingAmount PaymentStatus TariffCode      Remarks
# 1             0.00          Paid         T3          nan
# 29            0.00       Unknown         T3  Check meter
# 30            0.00       Unknown         T2     Replaced
# 66         2568.85       Unknown         T3     Replaced
# 99            0.00       Unknown         T3           OK
# ..             ...           ...        ...          ...
# 70            0.00          Paid         T1          nan
# 19            0.00       Unknown         T1           OK
# 176           0.00       Unknown         T2          nan
# 109           0.00          Paid         T3          nan
# 49            0.00       Unknown         T2          nan
#
# [173 rows x 10 columns]

# %% [markdown]
# ## 18. Extract columns: CustomerID, ReadingDate, Energy_kWh, BillingAmount

# %%
df1[['CustomerID', 'ReadingDate', 'Energy_kWh', 'BillingAmount']]
# Out:
#     CustomerID ReadingDate  Energy_kWh  BillingAmount
# 0        C0001  2023-01-02      753.59           0.00
# 1        C0002  2023-03-13    99999.00           0.00
# 2        C0003  2023-03-03    99999.00           0.00
# 3        C0004  2023-01-23    99999.00           0.00
# 4        C0005  2023-09-02     1075.76           0.00
# ..         ...         ...         ...            ...
# 195      C0196  2023-03-25    99999.00        2032.17
# 196      C0197  2023-05-22    99999.00           0.00
# 197      C0198  2023-06-25      581.91           0.00
# 198      C0199  2023-06-12    99999.00        1869.82
# 199      C0200  2023-04-24     1038.35           0.00
#
# [173 rows x 4 columns]

# %% [markdown]
# ## 19. Create a new column CostPerUnit = BillingAmount / Energy_kWh

# %%
df1['CostPerUnit'] = df1['BillingAmount'] / df1['Energy_kWh']
df1
# Out:
#     CustomerID MeterID Region ConnectionType ReadingDate  Energy_kWh  \
# 0        C0001   M6587   East     Commercial  2023-01-02      753.59
# 1        C0002   M9122   East    Residential  2023-03-13    99999.00
# 2        C0003   M1018  North     Commercial  2023-03-03    99999.00
# 3        C0004   M1615   West     Commercial  2023-01-23    99999.00
# 4        C0005   M7523  North    Residential  2023-09-02     1075.76
# ..         ...     ...    ...            ...         ...         ...
# 195      C0196   M7600  North     Commercial  2023-03-25    99999.00
# 196      C0197   M2103   East    Residential  2023-05-22    99999.00
# 197      C0198   M8002  South     Commercial  2023-06-25      581.91
# 198      C0199   M8029   West    Residential  2023-06-12    99999.00
# 199      C0200   M6029  South     Commercial  2023-04-24     1038.35
#
#      BillingAmount PaymentStatus TariffCode      Remarks  CostPerUnit
# 0             0.00          Paid         T3  Check meter     0.000000
# 1             0.00          Paid         T3          nan     0.000000
# 2             0.00          Paid         T2     Replaced     0.000000
# 3             0.00       Unknown         T2  Check meter     0.000000
# 4             0.00       Unknown         T2           OK     0.000000
# ..             ...           ...        ...          ...          ...
# 195        2032.17          Paid         T3           OK     0.020322
# 196           0.00          Paid         T3  Check meter     0.000000
# 197           0.00       Unknown         T2          nan     0.000000
# 198        1869.82        Unpaid         T1  Check meter     0.018698
# 199           0.00       Unknown         T1     Replaced     0.000000
#
# [173 rows x 11 columns]

# %% [markdown]
# ## 20. Export cleaned DataFrame to utility_meter_readings_cleaned.csv

# %%
df1.to_csv('utility_meter_readings_cleaned.csv')
